# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

#이미지가 저장될 폴더가 없다면 만듭니다.
import os
if not os.path.exists("./gan_images"):
    os.makedirs("./gan_images")

np.random.seed(3)
tf.random.set_seed(3)

# %%
#생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

# %%
#판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False

# %%
#생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential (Sequential)      (None, 28, 28, 1)         865281
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 212865
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________

# %%
#신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):

  # MNIST 데이터 불러오기

  (X_train, _), (_, _) = mnist.load_data()  # 앞서 불러온 적 있는 MNIST를 다시 이용합니다. 단, 테스트과정은 필요없고 이미지만 사용할 것이기 때문에 X_train만 불러왔습니다.
  X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
  X_train = (X_train - 127.5) / 127.5  # 픽셀값은 0에서 255사이의 값입니다. 이전에 255로 나누어 줄때는 이를 0~1사이의 값으로 바꾸었던 것인데, 여기서는 127.5를 빼준 뒤 127.5로 나누어 줌으로 인해 -1에서 1사이의 값으로 바뀌게 됩니다.
  #X_train.shape, Y_train.shape, X_test.shape, Y_test.shape

  true = np.ones((batch_size, 1))
  fake = np.zeros((batch_size, 1))

  for i in range(epoch):
          # 실제 데이터를 판별자에 입력하는 부분입니다.
          idx = np.random.randint(0, X_train.shape[0], batch_size)
          imgs = X_train[idx]
          d_loss_real = discriminator.train_on_batch(imgs, true)

          #가상 이미지를 판별자에 입력하는 부분입니다.
          noise = np.random.normal(0, 1, (batch_size, 100))
          gen_imgs = generator.predict(noise)
          d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

          #판별자와 생성자의 오차를 계산합니다.
          d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
          g_loss = gan.train_on_batch(noise, true)

          print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # 이부분은 중간 과정을 이미지로 저장해 주는 부분입니다. 본 장의 주요 내용과 관련이 없어
        # 소스코드만 첨부합니다. 만들어진 이미지들은 gan_images 폴더에 저장됩니다.
          if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("gan_images/gan_mnist_%d.png" % i)

gan_train(4001, 32, 200)  #4000번 반복되고(+1을 해 주는 것에 주의), 배치 사이즈는 32,  200번 마다 결과가 저장되게 하였습니다.
# Out:
# epoch:0  d_loss:0.7053  g_loss:0.6912
# epoch:1  d_loss:0.4617  g_loss:0.3278
# epoch:2  d_loss:0.5693  g_loss:0.1024
# epoch:3  d_loss:0.6593  g_loss:0.0837
# epoch:4  d_loss:0.5770  g_loss:0.1641
# epoch:5  d_loss:0.5092  g_loss:0.4206
# epoch:6  d_loss:0.4873  g_loss:0.6972
# epoch:7  d_loss:0.5090  g_loss:0.8721
# epoch:8  d_loss:0.4976  g_loss:0.8954
# epoch:9  d_loss:0.4877  g_loss:0.8695
# epoch:10  d_loss:0.4186  g_loss:0.7792
# epoch:11  d_loss:0.4463  g_loss:0.8067
# epoch:12  d_loss:0.4999  g_loss:0.8511
# epoch:13  d_loss:0.4883  g_loss:0.8900
# epoch:14  d_loss:0.5858  g_loss:0.9510
# epoch:15  d_loss:0.4796  g_loss:1.0425
# epoch:16  d_loss:0.4165  g_loss:1.0446
# epoch:17  d_loss:0.6310  g_loss:0.8198
# epoch:18  d_loss:0.5576  g_loss:0.6647
# epoch:19  d_loss:0.4578  g_loss:0.7245
# epoch:20  d_loss:0.4308  g_loss:0.7659
# epoch:21  d_loss:0.5038  g_loss:0.7922
# epoch:22  d_loss:0.5036  g_loss:0.6539
# epoch:23  d_loss:0.4523  g_loss:0.6055
# epoch:24  d_loss:0.4401  g_loss:0.6659
# epoch:25  d_loss:0.4545  g_loss:0.6574
# epoch:26  d_loss:0.4910  g_loss:0.6685
# epoch:27  d_loss:0.4376  g_loss:0.5914
# epoch:28  d_loss:0.4554  g_loss:0.5414
# epoch:29  d_loss:0.4758  g_loss:0.5407
# epoch:30  d_loss:0.4154  g_loss:0.6064
# epoch:31  d_loss:0.4112  g_loss:0.7118
# epoch:32  d_loss:0.3626  g_loss:0.5998
# epoch:33  d_loss:0.3276  g_loss:0.7496
# epoch:34  d_loss:0.2523  g_loss:0.8180
# epoch:35  d_loss:0.3088  g_loss:0.8609
# epoch:36  d_loss:0.3129  g_loss:0.7017
# epoch:37  d_loss:0.2593  g_loss:0.8897
# epoch:38  d_loss:0.2632  g_loss:1.0242
# epoch:39  d_loss:0.1754  g_loss:1.2879
# epoch:40  d_loss:0.2523  g_loss:1.2997
# epoch:41  d_loss:0.3301  g_loss:0.8615
# epoch:42  d_loss:0.3496  g_loss:0.7664
# epoch:43  d_loss:0.2408  g_loss:0.9441
# epoch:44  d_loss:0.2100  g_loss:1.2694
# epoch:45  d_loss:0.3206  g_loss:1.5373
# epoch:46  d_loss:0.7175  g_loss:0.8633
# epoch:47  d_loss:0.3498  g_loss:1.7506
# epoch:48  d_loss:0.1323  g_loss:2.8305
# epoch:49  d_loss:0.1506  g_loss:2.9498
# epoch:50  d_loss:0.0687  g_loss:2.5159
# epoch:51  d_loss:0.0872  g_loss:2.4430
# epoch:52  d_loss:0.1255  g_loss:2.7598
# epoch:53  d_loss:0.2170  g_loss:2.9791
# epoch:54  d_loss:0.2735  g_loss:3.5938
# epoch:55  d_loss:0.4124  g_loss:3.0079
# epoch:56  d_loss:0.7004  g_loss:1.8747
# epoch:57  d_loss:0.8181  g_loss:2.3882
# epoch:58  d_loss:0.7593  g_loss:3.1726
# epoch:59  d_loss:0.5183  g_loss:2.9224
# epoch:60  d_loss:0.5014  g_loss:2.6264
# epoch:61  d_loss:0.3720  g_loss:2.9863
# epoch:62  d_loss:0.3071  g_loss:3.7629
# epoch:63  d_loss:0.2275  g_loss:4.2113
# epoch:64  d_loss:0.5833  g_loss:3.0479
# epoch:65  d_loss:0.5593  g_loss:2.6052
# epoch:66  d_loss:0.6782  g_loss:2.1799
# epoch:67  d_loss:0.4699  g_loss:2.5041
# epoch:68  d_loss:0.3218  g_loss:3.6024
# epoch:69  d_loss:0.9009  g_loss:2.1977
# epoch:70  d_loss:1.0446  g_loss:0.9361
# epoch:71  d_loss:0.6320  g_loss:0.9278
# epoch:72  d_loss:0.6980  g_loss:1.6108
# epoch:73  d_loss:0.5100  g_loss:1.9951
# epoch:74  d_loss:0.6296  g_loss:1.8977
# epoch:75  d_loss:0.5577  g_loss:1.7104
# epoch:76  d_loss:0.5697  g_loss:1.1244
# epoch:77  d_loss:0.3831  g_loss:2.1270
# epoch:78  d_loss:0.2892  g_loss:3.0798
# epoch:79  d_loss:0.2025  g_loss:3.9608
# epoch:80  d_loss:0.3344  g_loss:3.4772
# epoch:81  d_loss:0.4722  g_loss:3.2107
# epoch:82  d_loss:0.4400  g_loss:2.6381
# epoch:83  d_loss:0.3438  g_loss:3.6330
# epoch:84  d_loss:0.4476  g_loss:3.7578
# epoch:85  d_loss:1.1656  g_loss:3.0135
# epoch:86  d_loss:0.6062  g_loss:3.2448
# epoch:87  d_loss:0.8344  g_loss:3.0134
# epoch:88  d_loss:0.8701  g_loss:2.8367
# epoch:89  d_loss:0.8182  g_loss:2.2649
# epoch:90  d_loss:0.6875  g_loss:2.1617
# epoch:91  d_loss:0.6599  g_loss:2.3339
# epoch:92  d_loss:0.6436  g_loss:2.1499
# epoch:93  d_loss:0.6398  g_loss:2.0798
# epoch:94  d_loss:0.5640  g_loss:1.6566
# epoch:95  d_loss:0.5290  g_loss:1.4529
# epoch:96  d_loss:0.4760  g_loss:1.7503
# epoch:97  d_loss:0.4837  g_loss:1.5222
# epoch:98  d_loss:0.4545  g_loss:1.5707
# epoch:99  d_loss:0.6004  g_loss:1.2947
# epoch:100  d_loss:0.5265  g_loss:1.2971
# epoch:101  d_loss:0.4363  g_loss:1.3090
# epoch:102  d_loss:0.4056  g_loss:1.3475
# epoch:103  d_loss:0.5251  g_loss:1.3191
# epoch:104  d_loss:0.3986  g_loss:1.2763
# epoch:105  d_loss:0.5830  g_loss:1.2314
# epoch:106  d_loss:0.5074  g_loss:0.9100
# epoch:107  d_loss:0.5266  g_loss:1.0344
# epoch:108  d_loss:0.5282  g_loss:1.2247
# epoch:109  d_loss:0.4451  g_loss:1.2123
# epoch:110  d_loss:0.4926  g_loss:1.3015
# epoch:111  d_loss:0.5419  g_loss:1.1083
# epoch:112  d_loss:0.4569  g_loss:1.2086
# epoch:113  d_loss:0.5772  g_loss:0.9210
# epoch:114  d_loss:0.6694  g_loss:0.8860
# epoch:115  d_loss:0.6649  g_loss:0.7755
# epoch:116  d_loss:0.6134  g_loss:0.9239
# epoch:117  d_loss:0.5758  g_loss:1.0092
# epoch:118  d_loss:0.6167  g_loss:1.0750
# epoch:119  d_loss:0.5420  g_loss:1.1428
# epoch:120  d_loss:0.6037  g_loss:1.1400
# epoch:121  d_loss:0.6142  g_loss:1.0699
# epoch:122  d_loss:0.7056  g_loss:1.1094
# epoch:123  d_loss:0.6019  g_loss:1.1216
# epoch:124  d_loss:0.4687  g_loss:1.1760
# epoch:125  d_loss:0.6283  g_loss:1.3587
# epoch:126  d_loss:0.4911  g_loss:1.4361
# epoch:127  d_loss:0.3177  g_loss:1.7731
# epoch:128  d_loss:0.3505  g_loss:1.9998
# epoch:129  d_loss:0.3268  g_loss:2.0639
# epoch:130  d_loss:0.3741  g_loss:1.8225
# epoch:131  d_loss:0.3897  g_loss:1.7405
# epoch:132  d_loss:0.4047  g_loss:1.7962
# epoch:133  d_loss:0.3757  g_loss:2.2793
# epoch:134  d_loss:0.2738  g_loss:2.6189
# epoch:135  d_loss:0.3135  g_loss:2.9287
# epoch:136  d_loss:0.5175  g_loss:2.2103
# epoch:137  d_loss:0.4771  g_loss:2.1738
# epoch:138  d_loss:0.5904  g_loss:1.9373
# epoch:139  d_loss:0.5311  g_loss:2.2852
# epoch:140  d_loss:0.5768  g_loss:2.4331
# epoch:141  d_loss:0.7629  g_loss:1.7969
# epoch:142  d_loss:0.9508  g_loss:1.7242
# epoch:143  d_loss:0.6961  g_loss:1.8258
# epoch:144  d_loss:0.6772  g_loss:1.8467
# epoch:145  d_loss:0.6248  g_loss:1.7885
# epoch:146  d_loss:0.6842  g_loss:1.6242
# epoch:147  d_loss:0.6239  g_loss:2.0574
# epoch:148  d_loss:0.6106  g_loss:1.8198
# epoch:149  d_loss:0.4912  g_loss:2.0215
# epoch:150  d_loss:0.5673  g_loss:1.6635
# epoch:151  d_loss:0.5509  g_loss:1.8439
# epoch:152  d_loss:0.4554  g_loss:1.7037
# epoch:153  d_loss:0.3888  g_loss:1.8533
# epoch:154  d_loss:0.3627  g_loss:1.6863
# epoch:155  d_loss:0.3739  g_loss:1.7500
# epoch:156  d_loss:0.3799  g_loss:1.6475
# epoch:157  d_loss:0.4271  g_loss:1.8948
# epoch:158  d_loss:0.3679  g_loss:1.8291
# epoch:159  d_loss:0.3826  g_loss:1.8572
# epoch:160  d_loss:0.2441  g_loss:1.8620
# epoch:161  d_loss:0.3119  g_loss:1.8877
# epoch:162  d_loss:0.4480  g_loss:1.7107
# epoch:163  d_loss:0.2915  g_loss:1.9260
# epoch:164  d_loss:0.2742  g_loss:1.9142
# epoch:165  d_loss:0.2148  g_loss:2.1126
# epoch:166  d_loss:0.3539  g_loss:2.0315
# epoch:167  d_loss:0.4098  g_loss:1.8034
# epoch:168  d_loss:0.3865  g_loss:1.7265
# epoch:169  d_loss:0.4787  g_loss:1.5245
# epoch:170  d_loss:0.4654  g_loss:1.1529
# epoch:171  d_loss:0.3778  g_loss:1.4494
# epoch:172  d_loss:0.3978  g_loss:1.5178
# epoch:173  d_loss:0.3584  g_loss:1.3224
# epoch:174  d_loss:0.6008  g_loss:1.3901
# epoch:175  d_loss:0.4764  g_loss:1.6922
# epoch:176  d_loss:0.7079  g_loss:1.6384
# epoch:177  d_loss:0.7394  g_loss:1.2452
# epoch:178  d_loss:0.3831  g_loss:1.3315
# epoch:179  d_loss:0.6699  g_loss:0.9795
# epoch:180  d_loss:0.7778  g_loss:0.8892
# epoch:181  d_loss:0.5466  g_loss:1.2232
# epoch:182  d_loss:0.7363  g_loss:1.4894
# epoch:183  d_loss:0.6739  g_loss:1.4891
# epoch:184  d_loss:0.6970  g_loss:1.4425
# epoch:185  d_loss:0.8040  g_loss:1.1638
# epoch:186  d_loss:0.7488  g_loss:0.9413
# epoch:187  d_loss:0.5978  g_loss:1.2719
# epoch:188  d_loss:0.5884  g_loss:1.3426
# epoch:189  d_loss:0.5428  g_loss:1.3152
# epoch:190  d_loss:0.5099  g_loss:1.3326
# epoch:191  d_loss:0.4878  g_loss:1.4669
# epoch:192  d_loss:0.4671  g_loss:1.4848
# epoch:193  d_loss:0.4858  g_loss:1.5538
# epoch:194  d_loss:0.5142  g_loss:1.6474
# epoch:195  d_loss:0.3842  g_loss:1.7394
# epoch:196  d_loss:0.3452  g_loss:1.8791
# epoch:197  d_loss:0.3550  g_loss:1.9196
# epoch:198  d_loss:0.2730  g_loss:1.8732
# epoch:199  d_loss:0.2705  g_loss:2.2927
# epoch:200  d_loss:0.3754  g_loss:2.1163
# epoch:201  d_loss:0.4843  g_loss:2.1975
# epoch:202  d_loss:0.3637  g_loss:2.1186
# epoch:203  d_loss:0.3290  g_loss:2.3450
# epoch:204  d_loss:0.3008  g_loss:2.3636
# epoch:205  d_loss:0.3816  g_loss:2.1069
# epoch:206  d_loss:0.3296  g_loss:2.2456
# epoch:207  d_loss:0.4419  g_loss:2.0983
# epoch:208  d_loss:0.4659  g_loss:2.0016
# epoch:209  d_loss:0.2614  g_loss:2.0860
# epoch:210  d_loss:0.4314  g_loss:2.1297
# epoch:211  d_loss:0.4489  g_loss:1.7915
# epoch:212  d_loss:0.4381  g_loss:1.8466
# epoch:213  d_loss:0.5164  g_loss:2.1236
# epoch:214  d_loss:0.4625  g_loss:1.9765
# epoch:215  d_loss:0.4179  g_loss:1.7598
# epoch:216  d_loss:0.6044  g_loss:1.8791
# epoch:217  d_loss:0.4373  g_loss:1.6120
# epoch:218  d_loss:0.4465  g_loss:1.6686
# epoch:219  d_loss:0.5025  g_loss:1.5804
# epoch:220  d_loss:0.4757  g_loss:1.5960
# epoch:221  d_loss:0.7635  g_loss:1.3110
# epoch:222  d_loss:0.5012  g_loss:1.4184
# epoch:223  d_loss:0.5141  g_loss:1.9045
# epoch:224  d_loss:0.6441  g_loss:1.6723
# epoch:225  d_loss:0.5635  g_loss:1.5432
# epoch:226  d_loss:0.4989  g_loss:1.7377
# epoch:227  d_loss:0.6532  g_loss:1.3154
# epoch:228  d_loss:0.5450  g_loss:1.5431
# epoch:229  d_loss:0.5180  g_loss:1.2782
# epoch:230  d_loss:0.6460  g_loss:1.7234
# epoch:231  d_loss:0.6732  g_loss:1.9067
# epoch:232  d_loss:0.7757  g_loss:1.7305
# epoch:233  d_loss:0.6795  g_loss:2.3435
# epoch:234  d_loss:0.5984  g_loss:1.5434
# epoch:235  d_loss:0.4583  g_loss:1.6198
# epoch:236  d_loss:0.4335  g_loss:1.3496
# epoch:237  d_loss:0.4398  g_loss:1.7640
# epoch:238  d_loss:0.4027  g_loss:2.1454
# epoch:239  d_loss:0.3332  g_loss:2.3316
# epoch:240  d_loss:0.3636  g_loss:2.3902
# epoch:241  d_loss:0.6019  g_loss:2.3959
# epoch:242  d_loss:0.3494  g_loss:2.4086
# epoch:243  d_loss:0.4857  g_loss:2.3524
# epoch:244  d_loss:0.3604  g_loss:2.2200
# epoch:245  d_loss:0.3755  g_loss:2.4171
# epoch:246  d_loss:0.3613  g_loss:2.9841
# epoch:247  d_loss:0.4628  g_loss:2.9194
# epoch:248  d_loss:0.3503  g_loss:2.8803
# epoch:249  d_loss:0.3612  g_loss:2.8287
# epoch:250  d_loss:0.4664  g_loss:2.5446
# epoch:251  d_loss:0.3739  g_loss:2.3902
# epoch:252  d_loss:0.3978  g_loss:2.3335
# epoch:253  d_loss:0.4143  g_loss:2.2790
# epoch:254  d_loss:0.5177  g_loss:2.2265
# epoch:255  d_loss:0.4698  g_loss:2.0571
# epoch:256  d_loss:0.4953  g_loss:2.2098
# epoch:257  d_loss:0.3169  g_loss:1.9033
# epoch:258  d_loss:0.5372  g_loss:1.8481
# epoch:259  d_loss:0.5851  g_loss:1.7743
# epoch:260  d_loss:0.4666  g_loss:2.2685
# epoch:261  d_loss:0.4181  g_loss:2.3404
# epoch:262  d_loss:0.5341  g_loss:2.2711
# epoch:263  d_loss:0.5090  g_loss:1.6571
# epoch:264  d_loss:0.4115  g_loss:1.8008
# epoch:265  d_loss:0.4959  g_loss:1.8888
# epoch:266  d_loss:0.3889  g_loss:2.2171
# epoch:267  d_loss:0.4497  g_loss:2.7880
# epoch:268  d_loss:0.3893  g_loss:2.2549
# epoch:269  d_loss:0.6040  g_loss:1.8892
# epoch:270  d_loss:0.3405  g_loss:1.7761
# epoch:271  d_loss:0.3465  g_loss:1.6067
# epoch:272  d_loss:0.3759  g_loss:1.9111
# epoch:273  d_loss:0.3873  g_loss:2.0444
# epoch:274  d_loss:0.4946  g_loss:2.0471
# epoch:275  d_loss:0.3959  g_loss:2.1002
# epoch:276  d_loss:0.5002  g_loss:1.7473
# epoch:277  d_loss:0.5946  g_loss:1.7441
# epoch:278  d_loss:0.4272  g_loss:1.8692
# epoch:279  d_loss:0.4218  g_loss:2.1290
# epoch:280  d_loss:0.3879  g_loss:2.2835
# epoch:281  d_loss:0.5051  g_loss:1.9746
# epoch:282  d_loss:0.4913  g_loss:1.8435
# epoch:283  d_loss:0.4885  g_loss:2.0770
# epoch:284  d_loss:0.5379  g_loss:1.8224
# epoch:285  d_loss:0.5322  g_loss:1.5392
# epoch:286  d_loss:0.4324  g_loss:2.1864
# epoch:287  d_loss:0.3836  g_loss:2.0180
# epoch:288  d_loss:0.3896  g_loss:2.4269
# epoch:289  d_loss:0.5283  g_loss:2.0283
# epoch:290  d_loss:0.6437  g_loss:1.6043
# epoch:291  d_loss:0.4712  g_loss:1.8863
# epoch:292  d_loss:0.4389  g_loss:1.6578
# epoch:293  d_loss:0.4914  g_loss:1.9297
# epoch:294  d_loss:0.3696  g_loss:2.2242
# epoch:295  d_loss:0.5394  g_loss:2.1930
# epoch:296  d_loss:0.4538  g_loss:1.6665
# epoch:297  d_loss:0.4958  g_loss:1.6803
# epoch:298  d_loss:0.5973  g_loss:1.8582
# epoch:299  d_loss:0.3349  g_loss:2.4985
# epoch:300  d_loss:0.4382  g_loss:2.3360
# epoch:301  d_loss:0.3718  g_loss:1.9712
# epoch:302  d_loss:0.3818  g_loss:1.7638
# epoch:303  d_loss:0.3818  g_loss:2.1010
# epoch:304  d_loss:0.3543  g_loss:1.9149
# epoch:305  d_loss:0.5228  g_loss:1.5750
# epoch:306  d_loss:0.2797  g_loss:2.0810
# epoch:307  d_loss:0.3446  g_loss:2.1409
# epoch:308  d_loss:0.3242  g_loss:2.4438
# epoch:309  d_loss:0.4168  g_loss:2.3491
# epoch:310  d_loss:0.4355  g_loss:1.6828
# epoch:311  d_loss:0.4103  g_loss:1.6029
# epoch:312  d_loss:0.5559  g_loss:1.5699
# epoch:313  d_loss:0.4916  g_loss:1.6467
# epoch:314  d_loss:0.3835  g_loss:2.2926
# epoch:315  d_loss:0.4144  g_loss:2.5631
# epoch:316  d_loss:0.5017  g_loss:2.2419
# epoch:317  d_loss:0.4075  g_loss:2.4195
# epoch:318  d_loss:0.5141  g_loss:1.8099
# epoch:319  d_loss:0.6534  g_loss:1.7701
# epoch:320  d_loss:0.4845  g_loss:1.7093
# epoch:321  d_loss:0.6952  g_loss:1.8760
# epoch:322  d_loss:0.4920  g_loss:2.1231
# epoch:323  d_loss:0.6202  g_loss:1.9402
# epoch:324  d_loss:0.5421  g_loss:1.7311
# epoch:325  d_loss:0.4886  g_loss:2.0739
# epoch:326  d_loss:0.4802  g_loss:1.7425
# epoch:327  d_loss:0.4697  g_loss:2.0888
# epoch:328  d_loss:0.4663  g_loss:2.5399
# epoch:329  d_loss:0.4035  g_loss:2.6650
# epoch:330  d_loss:0.6739  g_loss:2.3930
# epoch:331  d_loss:0.5258  g_loss:2.0962
# epoch:332  d_loss:0.4878  g_loss:1.9945
# epoch:333  d_loss:0.4101  g_loss:2.2523
# epoch:334  d_loss:0.4660  g_loss:1.8136
# epoch:335  d_loss:0.5670  g_loss:2.1924
# epoch:336  d_loss:0.3375  g_loss:2.4865
# epoch:337  d_loss:0.2731  g_loss:2.7313
# epoch:338  d_loss:0.4179  g_loss:2.8024
# epoch:339  d_loss:0.3412  g_loss:2.6774
# epoch:340  d_loss:0.2949  g_loss:2.3578
# epoch:341  d_loss:0.3567  g_loss:2.1286
# epoch:342  d_loss:0.3150  g_loss:2.1412
# epoch:343  d_loss:0.2641  g_loss:2.7783
# epoch:344  d_loss:0.3050  g_loss:2.8176
# epoch:345  d_loss:0.3393  g_loss:3.1960
# epoch:346  d_loss:0.3682  g_loss:3.1905
# epoch:347  d_loss:0.2755  g_loss:2.7610
# epoch:348  d_loss:0.2428  g_loss:2.9958
# epoch:349  d_loss:0.2372  g_loss:3.0086
# epoch:350  d_loss:0.3716  g_loss:2.7159
# epoch:351  d_loss:0.2771  g_loss:3.1023
# epoch:352  d_loss:0.3080  g_loss:3.0686
# epoch:353  d_loss:0.2083  g_loss:2.9765
# epoch:354  d_loss:0.4157  g_loss:2.4441
# epoch:355  d_loss:0.3157  g_loss:2.6418
# epoch:356  d_loss:0.2889  g_loss:2.8243
# epoch:357  d_loss:0.3119  g_loss:2.4756
# epoch:358  d_loss:0.2227  g_loss:2.3076
# epoch:359  d_loss:0.2323  g_loss:2.5002
# epoch:360  d_loss:0.2446  g_loss:2.8055
# epoch:361  d_loss:0.2545  g_loss:2.9016
# epoch:362  d_loss:0.2106  g_loss:2.7509
# epoch:363  d_loss:0.3766  g_loss:2.4972
# epoch:364  d_loss:0.3046  g_loss:1.9305
# epoch:365  d_loss:0.2992  g_loss:2.5964
# epoch:366  d_loss:0.2448  g_loss:3.4603
# epoch:367  d_loss:0.3650  g_loss:3.0889
# epoch:368  d_loss:0.4694  g_loss:2.5340
# epoch:369  d_loss:0.3733  g_loss:2.4626
# epoch:370  d_loss:0.5320  g_loss:1.9695
# epoch:371  d_loss:0.2323  g_loss:2.6121
# epoch:372  d_loss:0.4078  g_loss:2.6455
# epoch:373  d_loss:0.2705  g_loss:2.6091
# epoch:374  d_loss:0.2012  g_loss:2.4354
# epoch:375  d_loss:0.3812  g_loss:2.5313
# epoch:376  d_loss:0.4127  g_loss:1.9188
# epoch:377  d_loss:0.3139  g_loss:2.4149
# epoch:378  d_loss:0.3628  g_loss:2.8936
# epoch:379  d_loss:0.3375  g_loss:3.0560
# epoch:380  d_loss:0.5372  g_loss:2.1773
# epoch:381  d_loss:0.4575  g_loss:1.9627
# epoch:382  d_loss:0.3445  g_loss:1.5964
# epoch:383  d_loss:0.3517  g_loss:2.0664
# epoch:384  d_loss:0.3742  g_loss:2.3373
# epoch:385  d_loss:0.3855  g_loss:2.4132
# epoch:386  d_loss:0.3748  g_loss:2.3851
# epoch:387  d_loss:0.3767  g_loss:2.0512
# epoch:388  d_loss:0.6366  g_loss:1.4905
# epoch:389  d_loss:0.3416  g_loss:1.8466
# epoch:390  d_loss:0.5041  g_loss:1.8344
# epoch:391  d_loss:0.4959  g_loss:1.9340
# epoch:392  d_loss:0.4520  g_loss:2.0757
# epoch:393  d_loss:0.3457  g_loss:2.1475
# epoch:394  d_loss:0.4685  g_loss:1.5563
# epoch:395  d_loss:0.4103  g_loss:1.9922
# epoch:396  d_loss:0.4323  g_loss:2.3398
# epoch:397  d_loss:0.2963  g_loss:2.6350
# epoch:398  d_loss:0.5769  g_loss:1.7179
# epoch:399  d_loss:0.4594  g_loss:1.9608
# epoch:400  d_loss:0.3518  g_loss:1.8630
# epoch:401  d_loss:0.3879  g_loss:1.5955
# epoch:402  d_loss:0.4420  g_loss:1.9015
# epoch:403  d_loss:0.2698  g_loss:2.4504
# epoch:404  d_loss:0.3534  g_loss:2.2408
# epoch:405  d_loss:0.2655  g_loss:2.1384
# epoch:406  d_loss:0.4485  g_loss:1.9089
# epoch:407  d_loss:0.3538  g_loss:2.0501
# epoch:408  d_loss:0.4765  g_loss:2.0352
# epoch:409  d_loss:0.3557  g_loss:2.2030
# epoch:410  d_loss:0.4310  g_loss:1.9856
# epoch:411  d_loss:0.3937  g_loss:1.9401
# epoch:412  d_loss:0.3387  g_loss:1.8109
# epoch:413  d_loss:0.3704  g_loss:1.8495
# epoch:414  d_loss:0.5720  g_loss:1.5808
# epoch:415  d_loss:0.3747  g_loss:1.8245
# epoch:416  d_loss:0.4241  g_loss:1.9611
# epoch:417  d_loss:0.3082  g_loss:2.3366
# epoch:418  d_loss:0.3547  g_loss:2.6584
# epoch:419  d_loss:0.3455  g_loss:2.3312
# epoch:420  d_loss:0.2645  g_loss:2.2580
# epoch:421  d_loss:0.4537  g_loss:2.0253
# epoch:422  d_loss:0.3413  g_loss:2.3164
# epoch:423  d_loss:0.4410  g_loss:2.3725
# epoch:424  d_loss:0.3902  g_loss:2.5719
# epoch:425  d_loss:0.3239  g_loss:2.0420
# epoch:426  d_loss:0.2851  g_loss:2.1722
# epoch:427  d_loss:0.3483  g_loss:2.1144
# epoch:428  d_loss:0.3561  g_loss:2.2115
# epoch:429  d_loss:0.3350  g_loss:2.8098
# epoch:430  d_loss:0.3113  g_loss:2.9677
# epoch:431  d_loss:0.2834  g_loss:2.5672
# epoch:432  d_loss:0.2543  g_loss:2.9672
# epoch:433  d_loss:0.3603  g_loss:2.6056
# epoch:434  d_loss:0.4121  g_loss:2.4312
# epoch:435  d_loss:0.5847  g_loss:2.1842
# epoch:436  d_loss:0.2034  g_loss:2.7992
# epoch:437  d_loss:0.3888  g_loss:2.9874
# epoch:438  d_loss:0.3923  g_loss:2.6363
# epoch:439  d_loss:0.3167  g_loss:2.5233
# epoch:440  d_loss:0.4404  g_loss:2.2119
# epoch:441  d_loss:0.3403  g_loss:2.1859
# epoch:442  d_loss:0.3162  g_loss:2.0294
# epoch:443  d_loss:0.2403  g_loss:2.3375
# epoch:444  d_loss:0.3084  g_loss:2.6964
# epoch:445  d_loss:0.3085  g_loss:2.0278
# epoch:446  d_loss:0.3833  g_loss:2.2549
# epoch:447  d_loss:0.3674  g_loss:2.3717
# epoch:448  d_loss:0.3026  g_loss:2.6554
# epoch:449  d_loss:0.4693  g_loss:2.2865
# epoch:450  d_loss:0.4825  g_loss:1.9306
# epoch:451  d_loss:0.3974  g_loss:2.2234
# epoch:452  d_loss:0.3437  g_loss:2.5772
# epoch:453  d_loss:0.3371  g_loss:2.3567
# epoch:454  d_loss:0.3180  g_loss:2.2187
# epoch:455  d_loss:0.5381  g_loss:1.8368
# epoch:456  d_loss:0.5233  g_loss:1.8894
# epoch:457  d_loss:0.3232  g_loss:2.0241
# epoch:458  d_loss:0.3357  g_loss:1.9860
# epoch:459  d_loss:0.3246  g_loss:2.3377
# epoch:460  d_loss:0.3518  g_loss:2.3762
# epoch:461  d_loss:0.2934  g_loss:2.3048
# epoch:462  d_loss:0.2607  g_loss:2.4420
# epoch:463  d_loss:0.2845  g_loss:1.9714
# epoch:464  d_loss:0.2756  g_loss:2.0950
# epoch:465  d_loss:0.3106  g_loss:2.5303
# epoch:466  d_loss:0.3303  g_loss:2.2929
# epoch:467  d_loss:0.3276  g_loss:2.3136
# epoch:468  d_loss:0.2327  g_loss:2.2731
# epoch:469  d_loss:0.3289  g_loss:2.2057
# epoch:470  d_loss:0.3128  g_loss:2.4546
# epoch:471  d_loss:0.3015  g_loss:2.4918
# epoch:472  d_loss:0.1851  g_loss:2.2489
# epoch:473  d_loss:0.2838  g_loss:2.5952
# epoch:474  d_loss:0.2842  g_loss:2.8995
# epoch:475  d_loss:0.2767  g_loss:2.2382
# epoch:476  d_loss:0.1837  g_loss:2.4419
# epoch:477  d_loss:0.2527  g_loss:2.2104
# epoch:478  d_loss:0.2004  g_loss:2.2111
# epoch:479  d_loss:0.2670  g_loss:2.8644
# epoch:480  d_loss:0.2270  g_loss:2.8681
# epoch:481  d_loss:0.2075  g_loss:3.1860
# epoch:482  d_loss:0.2838  g_loss:2.5989
# epoch:483  d_loss:0.2666  g_loss:2.5292
# epoch:484  d_loss:0.1844  g_loss:2.5185
# epoch:485  d_loss:0.2015  g_loss:2.7243
# epoch:486  d_loss:0.3327  g_loss:2.4653
# epoch:487  d_loss:0.2985  g_loss:2.6797
# epoch:488  d_loss:0.2271  g_loss:2.2216
# epoch:489  d_loss:0.2621  g_loss:2.6390
# epoch:490  d_loss:0.3856  g_loss:3.0075
# epoch:491  d_loss:0.1540  g_loss:3.5493
# epoch:492  d_loss:0.3754  g_loss:2.4228
# epoch:493  d_loss:0.2756  g_loss:2.1705
# epoch:494  d_loss:0.2769  g_loss:2.2470
# epoch:495  d_loss:0.3587  g_loss:2.3274
# epoch:496  d_loss:0.2487  g_loss:2.6450
# epoch:497  d_loss:0.2177  g_loss:2.7488
# epoch:498  d_loss:0.3901  g_loss:2.3307
# epoch:499  d_loss:0.4067  g_loss:1.8883
# epoch:500  d_loss:0.2836  g_loss:2.0302
# epoch:501  d_loss:0.2701  g_loss:2.8481
# epoch:502  d_loss:0.2480  g_loss:2.8693
# epoch:503  d_loss:0.2521  g_loss:3.1449
# epoch:504  d_loss:0.2452  g_loss:2.8729
# epoch:505  d_loss:0.1980  g_loss:2.5870
# epoch:506  d_loss:0.3278  g_loss:2.0103
# epoch:507  d_loss:0.1698  g_loss:3.2094
# epoch:508  d_loss:0.1328  g_loss:3.2606
# epoch:509  d_loss:0.1687  g_loss:3.7146
# epoch:510  d_loss:0.2666  g_loss:2.9595
# epoch:511  d_loss:0.1917  g_loss:2.7409
# epoch:512  d_loss:0.3692  g_loss:2.6242
# epoch:513  d_loss:0.1199  g_loss:3.4136
# epoch:514  d_loss:0.1563  g_loss:3.5029
# epoch:515  d_loss:0.2246  g_loss:2.9821
# epoch:516  d_loss:0.1416  g_loss:3.0760
# epoch:517  d_loss:0.2071  g_loss:2.6214
# epoch:518  d_loss:0.2716  g_loss:2.7668
# epoch:519  d_loss:0.3284  g_loss:2.4235
# epoch:520  d_loss:0.2100  g_loss:2.7418
# epoch:521  d_loss:0.3434  g_loss:1.9405
# epoch:522  d_loss:0.2886  g_loss:2.6358
# epoch:523  d_loss:0.3244  g_loss:2.7419
# epoch:524  d_loss:0.3872  g_loss:2.2811
# epoch:525  d_loss:0.2697  g_loss:2.2955
# epoch:526  d_loss:0.2395  g_loss:2.6062
# epoch:527  d_loss:0.3068  g_loss:2.5335
# epoch:528  d_loss:0.2398  g_loss:2.7212
# epoch:529  d_loss:0.3230  g_loss:2.7167
# epoch:530  d_loss:0.2526  g_loss:1.8906
# epoch:531  d_loss:0.2435  g_loss:2.2649
# epoch:532  d_loss:0.1571  g_loss:2.7499
# epoch:533  d_loss:0.1560  g_loss:3.4521
# epoch:534  d_loss:0.1131  g_loss:3.2902
# epoch:535  d_loss:0.1660  g_loss:3.1248
# epoch:536  d_loss:0.1120  g_loss:3.1767
# epoch:537  d_loss:0.1185  g_loss:3.1714
# epoch:538  d_loss:0.1874  g_loss:2.8318
# epoch:539  d_loss:0.1706  g_loss:2.8611
# epoch:540  d_loss:0.1695  g_loss:3.1161
# epoch:541  d_loss:0.1550  g_loss:3.6283
# epoch:542  d_loss:0.1810  g_loss:3.4890
# epoch:543  d_loss:0.2623  g_loss:3.2223
# epoch:544  d_loss:0.3242  g_loss:2.1224
# epoch:545  d_loss:0.1883  g_loss:2.6075
# epoch:546  d_loss:0.2510  g_loss:2.6016
# epoch:547  d_loss:0.2206  g_loss:3.6118
# epoch:548  d_loss:0.1889  g_loss:3.0776
# epoch:549  d_loss:0.3942  g_loss:2.4074
# epoch:550  d_loss:0.3220  g_loss:2.2297
# epoch:551  d_loss:0.2608  g_loss:1.9630
# epoch:552  d_loss:0.4409  g_loss:2.4178
# epoch:553  d_loss:0.3496  g_loss:2.9432
# epoch:554  d_loss:0.3497  g_loss:2.3337
# epoch:555  d_loss:0.3060  g_loss:2.8659
# epoch:556  d_loss:0.3409  g_loss:2.5906
# epoch:557  d_loss:0.3164  g_loss:2.2490
# epoch:558  d_loss:0.4161  g_loss:2.2093
# epoch:559  d_loss:0.3052  g_loss:2.1926
# epoch:560  d_loss:0.4384  g_loss:2.1317
# epoch:561  d_loss:0.1797  g_loss:2.8626
# epoch:562  d_loss:0.2467  g_loss:3.0358
# epoch:563  d_loss:0.2550  g_loss:2.7338
# epoch:564  d_loss:0.2739  g_loss:3.0022
# epoch:565  d_loss:0.1204  g_loss:3.1516
# epoch:566  d_loss:0.0938  g_loss:2.7138
# epoch:567  d_loss:0.2048  g_loss:3.2000
# epoch:568  d_loss:0.1395  g_loss:3.1901
# epoch:569  d_loss:0.1582  g_loss:3.1937
# epoch:570  d_loss:0.1209  g_loss:3.1217
# epoch:571  d_loss:0.2239  g_loss:3.2001
# epoch:572  d_loss:0.1293  g_loss:2.6115
# epoch:573  d_loss:0.2200  g_loss:2.7289
# epoch:574  d_loss:0.1324  g_loss:2.5667
# epoch:575  d_loss:0.1302  g_loss:2.6875
# epoch:576  d_loss:0.1634  g_loss:2.7782
# epoch:577  d_loss:0.1446  g_loss:2.8962
# epoch:578  d_loss:0.2438  g_loss:3.0328
# epoch:579  d_loss:0.2303  g_loss:2.6164
# epoch:580  d_loss:0.1553  g_loss:3.3050
# epoch:581  d_loss:0.1478  g_loss:3.0987
# epoch:582  d_loss:0.2776  g_loss:2.5354
# epoch:583  d_loss:0.1412  g_loss:3.1023
# epoch:584  d_loss:0.1979  g_loss:3.6833
# epoch:585  d_loss:0.2795  g_loss:2.6366
# epoch:586  d_loss:0.1793  g_loss:3.5228
# epoch:587  d_loss:0.0927  g_loss:3.9321
# epoch:588  d_loss:0.2320  g_loss:4.4253
# epoch:589  d_loss:0.2967  g_loss:3.4452
# epoch:590  d_loss:0.4839  g_loss:2.5014
# epoch:591  d_loss:0.4203  g_loss:2.3044
# epoch:592  d_loss:0.1331  g_loss:4.4085
# epoch:593  d_loss:0.3875  g_loss:3.8895
# epoch:594  d_loss:0.2683  g_loss:3.0284
# epoch:595  d_loss:0.4590  g_loss:1.2564
# epoch:596  d_loss:0.4389  g_loss:1.2457
# epoch:597  d_loss:0.3118  g_loss:2.8316
# epoch:598  d_loss:0.2869  g_loss:3.4446
# epoch:599  d_loss:0.4599  g_loss:2.7344
# epoch:600  d_loss:0.3254  g_loss:1.9606
# epoch:601  d_loss:0.2471  g_loss:1.6524
# epoch:602  d_loss:0.3180  g_loss:1.8103
# epoch:603  d_loss:0.2430  g_loss:2.6856
# epoch:604  d_loss:0.2919  g_loss:2.3821
# epoch:605  d_loss:0.1572  g_loss:2.8725
# epoch:606  d_loss:0.2705  g_loss:2.6726
