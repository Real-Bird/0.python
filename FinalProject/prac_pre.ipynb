# %%
import numpy as np
import cv2 as cv
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from keras.models import load_model
model = load_model('tn_model.h5')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 128)       147584
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

test1 = plt.imread('unnamed.jpg')
plt.imshow(test1);

# %%
test_num = plt.imread('unnamed.jpg')
test_num = test_num[:,:,0]
test_num = test_num.astype('float32')

plt.imshow(test_num, cmap='Greys', interpolation='nearest');

test_num = test_num.reshape((1, 150, 150, 1))

print('The Answer is ', model.predict_classes(test_num))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25256/3506157637.py in <module>
#       7 test_num = test_num.reshape((1, 150, 150, 1))
#       8
# ----> 9 print('The Answer is ', model.predict_classes(test_num))
#
# D:\Program Files\python38\lib\site-packages\keras\engine\sequential.py in predict_classes(self, x, batch_size, verbose)
#     457                   '  if your model does binary classification '
#     458                   '  (e.g. if it uses a `sigmoid` last-layer activation).')
# --> 459     proba = self.predict(x, batch_size=batch_size, verbose=verbose)
#     460     if proba.shape[-1] > 1:
#     461       return proba.argmax(axis=-1)
#
# D:\Program Files\python38\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
# ...
