# %%
from keras.preprocessing.text import Tokenizer
samples = ['The cat sat on the mat.', 'The dog ate my homework.']

# 가장 빈도가 높은 1,000개의 단어만 선택하도록 Tokenizer 객체 생성
tokenizer = #TODO

# %%
# 단어 인덱스를 구축
tokenizer#TODO 

word_index = #TODO 
print("각 단어의 인덱스: \n", word_index)
# Out:
# 각 단어의 인덱스:
#  {'the': 1, 'cat': 2, 'sat': 3, 'on': 4, 'mat': 5, 'dog': 6, 'ate': 7, 'my': 8, 'homework': 9}

# %%
# 문자열을 정수 인덱스의 리스트로 변환
sequences = tokenizer#TODO 
print("sequences",  sequences  )
# Out:
# sequences [[1, 2, 3, 4, 1, 5], [1, 6, 7, 8, 9]]

# %%
print("index_word :" , tokenizer#TODO  )
print("단어 출현 빈도수 : " , tokenizer.#TODO  )
print("문장 수 : " , tokenizer.#TODO ) #문장 수
# Out:
# index_word : {1: 'the', 2: 'cat', 3: 'sat', 4: 'on', 5: 'mat', 6: 'dog', 7: 'ate', 8: 'my', 9: 'homework'}
# 단어 출현 빈도수 :  defaultdict(<class 'int'>, {2: 2, 1: 4, 4: 2, 5: 2, 3: 2, 9: 2, 8: 2, 6: 2, 7: 2})
# 문장 수 :  4
