# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
airline = pd.read_csv('airline_passengers.csv', index_col='Month')

# %%
airline.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
airline.index = pd.to_datetime(airline.index)
airline.head()
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121

# %%
from stats

result = #TODO   airline['Thousands of Passengers'], model='multiplicative')

# %%
def plot_decompose(decomposeresult):
    fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1, figsize=(15,8))
    decomposeresult.#TODO  (legend=False, ax=ax1)
    ax1.set_ylabel('Observerd')
    decomposeresult#TODO (legend=False, ax=ax2)
    ax2.set_ylabel('Trend')
    decomposeresult#TODO (legend=False, ax=ax3)
    ax3.set_ylabel('Seasonal')
    decomposeresult#TODO  (legend=False, ax=ax4)
    ax4.set_ylabel('Resid')

# %%
#TODO
