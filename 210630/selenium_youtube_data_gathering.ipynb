# %% [markdown]
# ### 유튜브 데이터 수집
# 1. 화면에서 검색어를 입력
# 2. selenium으로 키워드 검색
#     - source => soup
# 3. 검색 결과를 수집
#     - "h3", {"class":"title-and-badge style-scope ytd-video-renderer"}
#     - video type
#         + 채널명, 영상제목, 영상url, 조회수, 영상등록날짜
#         - video_df
#     - "div", {"class":"style-scope ytd-playlist-renderer"}
#     - playlist type
#         + 채널명, 재생목록제목, 재생목록url
#         - playlist_df

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from bs4 import BeautifulSoup

driver = webdriver.Chrome("d:/python/chromedriver")

# %%
keyword = input()
url  = "https://www.youtube.com/results?search_query=" + keyword
driver.get(url)
# Out:
# 코딩

# %%
source = driver.page_source

# %%
soup = BeautifulSoup(source, "html.parser")

# %%
video_type = soup.find_all("div", {"id":"dismissible"})

# %%
playlist_type = soup.find_all("div", {"class":"style-scope ytd-playlist-renderer"})

# %%
total_vd = []

for item in video_type:
        ch_name = item.find("tp-yt-paper-tooltip", {"class": "style-scope ytd-channel-name"}).text.replace("\n","").strip()
        print("ch_name = ", ch_name)
        title = item.find("yt-formatted-string",{"class":"style-scope ytd-video-renderer"}).text
        print("title = ", title)
        link = "youtube.com"+item.find("a",{"class":"yt-simple-endpoint style-scope ytd-video-renderer"})["href"]
        print("link = ", link)
        hit = item.find_all("span",{"class" : "style-scope ytd-video-meta-block"})[0].text.split("조회수")[1]
        print("hit = ", hit)
        regdate = item.find_all("span",{"class" : "style-scope ytd-video-meta-block"})[1].text
        print("regdate = ", regdate)
        print("-"*30)
        total_vd.append([ch_name, title, link, hit, regdate])
# Out:
# ch_name =  yanu_연우
# title =  [ 𝑷𝒍𝒂𝒚𝒍𝒊𝒔𝒕 ]  코딩할때 듣기 좋은 노래 • lofi type beat • 3 hours
# link =  youtube.com/watch?v=cbuZfY2S2UQ
# hit =   1435만회
# regdate =  1년 전
# ------------------------------
# ch_name =  Lofi 코딩
# title =  [ 𝑷𝒍𝒂𝒚𝒍𝒊𝒔𝒕 ] 코딩할때 듣기 좋은 노래 | 3 hour playlist | Lofi hip hop mix ~ jazzhop ~ relax beats
# link =  youtube.com/watch?v=Xc1Le3CSdrM
# hit =   69만회
# regdate =  6개월 전
# ------------------------------
# ch_name =  나도코딩
# title =  파이썬 코딩 무료 강의 (기본편) - 6시간 뒤면 여러분도 개발자가 될 수 있어요 [나도코딩]
# link =  youtube.com/watch?v=kWiCuklohdY
# hit =   205만회
# regdate =  1년 전
# ------------------------------
# ch_name =  Mood Rainbow
# title =  코딩할 때 듣기 좋은 로파이 재즈 힙합  (playlist)/𝕝𝕠𝕗𝕚 𝕛𝕒𝕫𝕫 𝕙𝕚𝕡𝕙𝕠𝕡 𝟙𝕙𝕣
# link =  youtube.com/watch?v=nxKfi-6EtmY
# hit =   226만회
# regdate =  1년 전
# ------------------------------
# ch_name =  조코딩 JoCoding
# title =  코딩 배워서 앱, 웹 만들고 싶으신가요? 코딩 공부 순서 정리해드립니다.
# link =  youtube.com/watch?v=wpUiN5hBnyc
# hit =   108만회
# regdate =  2년 전
# ------------------------------
# ch_name =  Musictag
# title =  코딩 & 공부할때 듣는 음악 - 집중할때 듣기 좋은 편안한 Lo-Fi 재즈
# link =  youtube.com/watch?v=CfPxlb8-ZQ0
# hit =   360만회
# regdate =  11개월 전
# ------------------------------
# ch_name =  brian
# title =  코딩이란? 코딩이란 무엇일까요? 초등학생들도 알아 듣기 쉬운 코딩 설명
# link =  youtube.com/watch?v=CeFoAu95P9M
# hit =   1.1만회
# regdate =  2년 전
# ------------------------------
# ch_name =  Lofi 코딩
# title =  [ 𝑷𝒍𝒂𝒚𝒍𝒊𝒔𝒕 ] 코딩 / 과제 할 때 집중 해서 듣기 좋은 음악 • 3 Hour Lofi Hip Hop Chill Music 📚 Relax Study Music
# link =  youtube.com/watch?v=HT2rbv_-MOg
# hit =   49만회
# regdate =  4개월 전
# ------------------------------
# ch_name =  Lofi 코딩
# title =  [ 𝑷𝒍𝒂𝒚𝒍𝒊𝒔𝒕 ] 코딩 / 과제 할 때 집중 해서 듣기 좋은 음악 • 3 Hour Lofi Hip Hop Chill Music 📚 Relax Study Music
# link =  youtube.com/watch?v=HT2rbv_-MOg
# hit =   49만회
# regdate =  4개월 전
# ------------------------------
# ch_name =  Lofi 코딩
# title =  [ 𝑷𝒍𝒂𝒚𝒍𝒊𝒔𝒕 ] 코딩 / 과제 할 때 집중 해서 듣기 좋은 음악 • 3 hour playlist • study lofi beat 📋
# link =  youtube.com/watch?v=Vdxp5H2vOdU
# hit =   35만회
# regdate =  3개월 전
# ------------------------------
# ch_name =  율yul
# title =  코딩 1도 모르던 문과생이 개발자 된 썰 | 취업 전후로 알았으면 좋았을 것들 |해외취업|  좋아하는 일 vs 잘하는 일 | 부트캠프 vs 국비지원 | 개발 적성, 취준생, 직장인
# link =  youtube.com/watch?v=3WXxFQv0xJM
# hit =   2.4만회
# regdate =  2개월 전
# ------------------------------
# ch_name =  #include 〈music.h〉
# title =  [지브리 스튜디오] 공부할때, 일할때 듣기좋은 음악 모음 12시간(검은화면) (12hours)(피아노)(Relaxing Piano Studio Ghibli Collection)
# link =  youtube.com/watch?v=wnudr9qjrbA
# hit =   435만회
# regdate =  1년 전
# ------------------------------
# ch_name =  인프런 - 지식을 배우고 나눠요
# title =  코딩 / 과제 할 때 집중 해서 듣기 좋은 음악🌃 | 3 hour playlist | beats to coding to | lofi, jazz, hiphop |
# link =  youtube.com/watch?v=0xJxgvJO2Xo
# hit =   75만회
# regdate =  1년 전
# ------------------------------
# ch_name =  SBS 뉴스
# title =  취업전선에 부는 ’코딩 열풍‘...실상은? / SBS / 후스토리
# link =  youtube.com/watch?v=u_kvcvvqTes
# hit =   22만회
# regdate =  3주 전
# ------------------------------
# ch_name =  스파르타 코딩클럽
# title =  코딩 처음 시작 방법? 독학 순서? 자세히 알려드립니다! l 현직 개발자가 말하는 Codidic
# link =  youtube.com/watch?v=erFhR4CO5Js
# hit =   2.6만회
# regdate =  6개월 전
# ------------------------------
# ch_name =  스파르타 코딩클럽
# title =  코딩 처음 시작 방법? 독학 순서? 자세히 알려드립니다! l 현직 개발자가 말하는 Codidic
# link =  youtube.com/watch?v=erFhR4CO5Js
# hit =   2.6만회
# regdate =  6개월 전
# ------------------------------
# ch_name =  tvN
# title =  (4화 풀버전) 요즘 초등학생은 다 배운다는 코딩, 모두가 코딩을 배워야 하는 진짜 이유.zipㅣ EP4-11
# link =  youtube.com/watch?v=j4HGOpBWvXM
# hit =   68만회
# regdate =  2년 전
# ------------------------------
# ch_name =  hyosung lim임효성
# title =  비전공자가 한달동안 코딩을 배우면 얼마나 성장할까?
# link =  youtube.com/watch?v=ufupPuN8VVw
# hit =   56만회
# regdate =  10개월 전
# ------------------------------
# ch_name =  Lofi 코딩
# title =  [ 𝑷𝒍𝒂𝒚𝒍𝒊𝒔𝒕 ] 코딩할때 듣기 좋은 노래 | 2 hour playlist | lofi hip hop mix ~ jazzhop ~ relax beats
# link =  youtube.com/watch?v=5U6rjsYJ8vU
# hit =   707회
# regdate =  1일 전
# ------------------------------
# ch_name =  코딩알려주는누나
# title =  이런분들은 코딩 배워도 실패합니다. 부트캠프 강사가 말하는 개발자 될놈과 안될놈
# link =  youtube.com/watch?v=tMIl7fcVXJY
# hit =   2.8천회
# regdate =  3주 전
# ------------------------------
# ch_name =  빵굽는개발자 빵형
# title =  [알고리즘] 카카오 코딩 테스트 #1
# link =  youtube.com/watch?v=ExaatgwYqfU
# hit =   62만회
# regdate =  3년 전
# ------------------------------
# ch_name =  코딩어TV
# title =  코딩 초보를 위한 기초 개념정리 1편 [프로그래밍 언어]
# link =  youtube.com/watch?v=MZKlECVAgdA
# hit =   7.3만회
# regdate =  2년 전
# ------------------------------
# ch_name =  EO
# title =  코딩 꿈나무들을 위한 토크콘서트 | NYPC x EO
# link =  youtube.com/watch?v=q5FqMdeCK74
# hit =   1.2만회
# regdate =  스트리밍 시간: 19시간 전
# ------------------------------
# ch_name =  Lofi 코딩
# title =  [ 𝑷𝒍𝒂𝒚𝒍𝒊𝒔𝒕 ] 코딩할때 듣기 좋은 노래 | 3 hour playlist | lofi hip hop mix ~ jazzhop ~ relax beats
# link =  youtube.com/watch?v=RMr30hkzu7w
# hit =   2.2만회
# regdate =  1개월 전
# ------------------------------
# ch_name =  그랩의 IT 열차
# title =  이 MBTI 유형은 코딩 꼭 해야됩니다
# link =  youtube.com/watch?v=57jM_sjF838
# hit =   2.4만회
# regdate =  11개월 전
# ------------------------------
# ch_name =  버클리 클라쓰
# title =  학원강사들 보다 코딩 개발을 잘 가르치는 유튜버들 추천! 특히 독학할때 코딩강의 보세요
# link =  youtube.com/watch?v=Ewm26mU7FZY
# hit =   25만회
# regdate =  10개월 전
# ------------------------------
# ch_name =  EBSCulture (EBS 교양)
# title =  코딩, 소프트웨어 시대 - 어렵지 않은 이야기, 코딩이란?
# link =  youtube.com/watch?v=KhptxxfMQ_Q
# hit =   25만회
# regdate =  6년 전
# ------------------------------

# %%
total_pl = []

for item in playlist_type:
        ch_name = item.find("tp-yt-paper-tooltip", {"class": "style-scope ytd-channel-name"}).text.replace("\n","").strip()
        print("ch_name = ", ch_name)
        title = item.find("h3", {"class": "style-scope ytd-playlist-renderer"}).text.replace("\n","").strip()
        print("title = ", title)
        link = "youtube.com"+item.find("a",{"class":"yt-simple-endpoint style-scope ytd-playlist-renderer"})["href"]
        print("link = ",link)
        print("-"*30)
        total_pl.append([ch_name, title, link])

# %%
import pandas as pd

# %%
vd_df = pd.DataFrame(total_vd,columns=["ch_name", "title", "link", "hit", "regdate"])
vd_df
# Out:
#                 ch_name                                              title  \
# 0               yanu_연우  [ 𝑷𝒍𝒂𝒚𝒍𝒊𝒔𝒕 ]  코딩할때 듣기 좋은 노래 • lofi type beat •...
# 1               Lofi 코딩  [ 𝑷𝒍𝒂𝒚𝒍𝒊𝒔𝒕 ] 코딩할때 듣기 좋은 노래 | 3 hour playlist |...
# 2                  나도코딩  파이썬 코딩 무료 강의 (기본편) - 6시간 뒤면 여러분도 개발자가 될 수 있어요 ...
# 3          Mood Rainbow  코딩할 때 듣기 좋은 로파이 재즈 힙합  (playlist)/𝕝𝕠𝕗𝕚 𝕛𝕒𝕫𝕫 𝕙𝕚...
# 4          조코딩 JoCoding           코딩 배워서 앱, 웹 만들고 싶으신가요? 코딩 공부 순서 정리해드립니다.
# 5              Musictag          코딩 & 공부할때 듣는 음악 - 집중할때 듣기 좋은 편안한 Lo-Fi 재즈
# 6                 brian            코딩이란? 코딩이란 무엇일까요? 초등학생들도 알아 듣기 쉬운 코딩 설명
# 7               Lofi 코딩  [ 𝑷𝒍𝒂𝒚𝒍𝒊𝒔𝒕 ] 코딩 / 과제 할 때 집중 해서 듣기 좋은 음악 • 3 Ho...
# 8               Lofi 코딩  [ 𝑷𝒍𝒂𝒚𝒍𝒊𝒔𝒕 ] 코딩 / 과제 할 때 집중 해서 듣기 좋은 음악 • 3 Ho...
# 9               Lofi 코딩  [ 𝑷𝒍𝒂𝒚𝒍𝒊𝒔𝒕 ] 코딩 / 과제 할 때 집중 해서 듣기 좋은 음악 • 3 ho...
# 10                 율yul  코딩 1도 모르던 문과생이 개발자 된 썰 | 취업 전후로 알았으면 좋았을 것들 |해...
# 11   #include 〈music.h〉  [지브리 스튜디오] 공부할때, 일할때 듣기좋은 음악 모음 12시간(검은화면) (12...
# 12    인프런 - 지식을 배우고 나눠요  코딩 / 과제 할 때 집중 해서 듣기 좋은 음악🌃 | 3 hour playlist ...
# 13               SBS 뉴스               취업전선에 부는 ’코딩 열풍‘...실상은? / SBS / 후스토리
# 14            스파르타 코딩클럽  코딩 처음 시작 방법? 독학 순서? 자세히 알려드립니다! l 현직 개발자가 말하는 ...
# 15            스파르타 코딩클럽  코딩 처음 시작 방법? 독학 순서? 자세히 알려드립니다! l 현직 개발자가 말하는 ...
# 16                  tvN  (4화 풀버전) 요즘 초등학생은 다 배운다는 코딩, 모두가 코딩을 배워야 하는 진짜...
# 17       hyosung lim임효성                       비전공자가 한달동안 코딩을 배우면 얼마나 성장할까?
# 18              Lofi 코딩  [ 𝑷𝒍𝒂𝒚𝒍𝒊𝒔𝒕 ] 코딩할때 듣기 좋은 노래 | 2 hour playlist |...
# 19             코딩알려주는누나       이런분들은 코딩 배워도 실패합니다. 부트캠프 강사가 말하는 개발자 될놈과 안될놈
# 20            빵굽는개발자 빵형                               [알고리즘] 카카오 코딩 테스트 #1
# 21                코딩어TV                    코딩 초보를 위한 기초 개념정리 1편 [프로그래밍 언어]
# 22                   EO                      코딩 꿈나무들을 위한 토크콘서트 | NYPC x EO
# 23              Lofi 코딩  [ 𝑷𝒍𝒂𝒚𝒍𝒊𝒔𝒕 ] 코딩할때 듣기 좋은 노래 | 3 hour playlist |...
# 24            그랩의 IT 열차                              이 MBTI 유형은 코딩 꼭 해야됩니다
# 25              버클리 클라쓰   학원강사들 보다 코딩 개발을 잘 가르치는 유튜버들 추천! 특히 독학할때 코딩강의 보세요
# 26  EBSCulture (EBS 교양)                   코딩, 소프트웨어 시대 - 어렵지 않은 이야기, 코딩이란?
#
#                                link      hit          regdate
# 0   youtube.com/watch?v=cbuZfY2S2UQ   1435만회             1년 전
# 1   youtube.com/watch?v=Xc1Le3CSdrM     69만회            6개월 전
# 2   youtube.com/watch?v=kWiCuklohdY    205만회             1년 전
# 3   youtube.com/watch?v=nxKfi-6EtmY    226만회             1년 전
# 4   youtube.com/watch?v=wpUiN5hBnyc    108만회             2년 전
# 5   youtube.com/watch?v=CfPxlb8-ZQ0    360만회           11개월 전
# 6   youtube.com/watch?v=CeFoAu95P9M    1.1만회             2년 전
# 7   youtube.com/watch?v=HT2rbv_-MOg     49만회            4개월 전
# 8   youtube.com/watch?v=HT2rbv_-MOg     49만회            4개월 전
# 9   youtube.com/watch?v=Vdxp5H2vOdU     35만회            3개월 전
# 10  youtube.com/watch?v=3WXxFQv0xJM    2.4만회            2개월 전
# 11  youtube.com/watch?v=wnudr9qjrbA    435만회             1년 전
# 12  youtube.com/watch?v=0xJxgvJO2Xo     75만회             1년 전
# 13  youtube.com/watch?v=u_kvcvvqTes     22만회             3주 전
# 14  youtube.com/watch?v=erFhR4CO5Js    2.6만회            6개월 전
# 15  youtube.com/watch?v=erFhR4CO5Js    2.6만회            6개월 전
# 16  youtube.com/watch?v=j4HGOpBWvXM     68만회             2년 전
# 17  youtube.com/watch?v=ufupPuN8VVw     56만회           10개월 전
# 18  youtube.com/watch?v=5U6rjsYJ8vU     707회             1일 전
# 19  youtube.com/watch?v=tMIl7fcVXJY    2.8천회             3주 전
# 20  youtube.com/watch?v=ExaatgwYqfU     62만회             3년 전
# 21  youtube.com/watch?v=MZKlECVAgdA    7.3만회             2년 전
# 22  youtube.com/watch?v=q5FqMdeCK74    1.2만회  스트리밍 시간: 19시간 전
# 23  youtube.com/watch?v=RMr30hkzu7w    2.2만회            1개월 전
# 24  youtube.com/watch?v=57jM_sjF838    2.4만회           11개월 전
# 25  youtube.com/watch?v=Ewm26mU7FZY     25만회           10개월 전
# 26  youtube.com/watch?v=KhptxxfMQ_Q     25만회             6년 전

# %%
pl_df = pd.DataFrame(total_pl,columns=["ch_name", "title", "link"])
pl_df
# Out:
# Empty DataFrame
# Columns: [ch_name, title, link]
# Index: []

# %%
vd_df.to_csv("video_type_youtube.csv", index=False)
pl_df.to_csv("playlist_type_youtube.csv", index=False)

# %%
pd.read_csv("video_type_youtube.csv")
# Out:
#                 ch_name                                              title  \
# 0               yanu_연우  [ 𝑷𝒍𝒂𝒚𝒍𝒊𝒔𝒕 ]  코딩할때 듣기 좋은 노래 • lofi type beat •...
# 1               Lofi 코딩  [ 𝑷𝒍𝒂𝒚𝒍𝒊𝒔𝒕 ] 코딩할때 듣기 좋은 노래 | 3 hour playlist |...
# 2                  나도코딩  파이썬 코딩 무료 강의 (기본편) - 6시간 뒤면 여러분도 개발자가 될 수 있어요 ...
# 3          Mood Rainbow  코딩할 때 듣기 좋은 로파이 재즈 힙합  (playlist)/𝕝𝕠𝕗𝕚 𝕛𝕒𝕫𝕫 𝕙𝕚...
# 4          조코딩 JoCoding           코딩 배워서 앱, 웹 만들고 싶으신가요? 코딩 공부 순서 정리해드립니다.
# 5              Musictag          코딩 & 공부할때 듣는 음악 - 집중할때 듣기 좋은 편안한 Lo-Fi 재즈
# 6                 brian            코딩이란? 코딩이란 무엇일까요? 초등학생들도 알아 듣기 쉬운 코딩 설명
# 7               Lofi 코딩  [ 𝑷𝒍𝒂𝒚𝒍𝒊𝒔𝒕 ] 코딩 / 과제 할 때 집중 해서 듣기 좋은 음악 • 3 Ho...
# 8               Lofi 코딩  [ 𝑷𝒍𝒂𝒚𝒍𝒊𝒔𝒕 ] 코딩 / 과제 할 때 집중 해서 듣기 좋은 음악 • 3 Ho...
# 9               Lofi 코딩  [ 𝑷𝒍𝒂𝒚𝒍𝒊𝒔𝒕 ] 코딩 / 과제 할 때 집중 해서 듣기 좋은 음악 • 3 ho...
# 10                 율yul  코딩 1도 모르던 문과생이 개발자 된 썰 | 취업 전후로 알았으면 좋았을 것들 |해...
# 11   #include 〈music.h〉  [지브리 스튜디오] 공부할때, 일할때 듣기좋은 음악 모음 12시간(검은화면) (12...
# 12    인프런 - 지식을 배우고 나눠요  코딩 / 과제 할 때 집중 해서 듣기 좋은 음악🌃 | 3 hour playlist ...
# 13               SBS 뉴스               취업전선에 부는 ’코딩 열풍‘...실상은? / SBS / 후스토리
# 14            스파르타 코딩클럽  코딩 처음 시작 방법? 독학 순서? 자세히 알려드립니다! l 현직 개발자가 말하는 ...
# 15            스파르타 코딩클럽  코딩 처음 시작 방법? 독학 순서? 자세히 알려드립니다! l 현직 개발자가 말하는 ...
# 16                  tvN  (4화 풀버전) 요즘 초등학생은 다 배운다는 코딩, 모두가 코딩을 배워야 하는 진짜...
# 17       hyosung lim임효성                       비전공자가 한달동안 코딩을 배우면 얼마나 성장할까?
# 18              Lofi 코딩  [ 𝑷𝒍𝒂𝒚𝒍𝒊𝒔𝒕 ] 코딩할때 듣기 좋은 노래 | 2 hour playlist |...
# 19             코딩알려주는누나       이런분들은 코딩 배워도 실패합니다. 부트캠프 강사가 말하는 개발자 될놈과 안될놈
# 20            빵굽는개발자 빵형                               [알고리즘] 카카오 코딩 테스트 #1
# 21                코딩어TV                    코딩 초보를 위한 기초 개념정리 1편 [프로그래밍 언어]
# 22                   EO                      코딩 꿈나무들을 위한 토크콘서트 | NYPC x EO
# 23              Lofi 코딩  [ 𝑷𝒍𝒂𝒚𝒍𝒊𝒔𝒕 ] 코딩할때 듣기 좋은 노래 | 3 hour playlist |...
# 24            그랩의 IT 열차                              이 MBTI 유형은 코딩 꼭 해야됩니다
# 25              버클리 클라쓰   학원강사들 보다 코딩 개발을 잘 가르치는 유튜버들 추천! 특히 독학할때 코딩강의 보세요
# 26  EBSCulture (EBS 교양)                   코딩, 소프트웨어 시대 - 어렵지 않은 이야기, 코딩이란?
#
#                                link      hit          regdate
# 0   youtube.com/watch?v=cbuZfY2S2UQ   1435만회             1년 전
# 1   youtube.com/watch?v=Xc1Le3CSdrM     69만회            6개월 전
# 2   youtube.com/watch?v=kWiCuklohdY    205만회             1년 전
# 3   youtube.com/watch?v=nxKfi-6EtmY    226만회             1년 전
# 4   youtube.com/watch?v=wpUiN5hBnyc    108만회             2년 전
# 5   youtube.com/watch?v=CfPxlb8-ZQ0    360만회           11개월 전
# 6   youtube.com/watch?v=CeFoAu95P9M    1.1만회             2년 전
# 7   youtube.com/watch?v=HT2rbv_-MOg     49만회            4개월 전
# 8   youtube.com/watch?v=HT2rbv_-MOg     49만회            4개월 전
# 9   youtube.com/watch?v=Vdxp5H2vOdU     35만회            3개월 전
# 10  youtube.com/watch?v=3WXxFQv0xJM    2.4만회            2개월 전
# 11  youtube.com/watch?v=wnudr9qjrbA    435만회             1년 전
# 12  youtube.com/watch?v=0xJxgvJO2Xo     75만회             1년 전
# 13  youtube.com/watch?v=u_kvcvvqTes     22만회             3주 전
# 14  youtube.com/watch?v=erFhR4CO5Js    2.6만회            6개월 전
# 15  youtube.com/watch?v=erFhR4CO5Js    2.6만회            6개월 전
# 16  youtube.com/watch?v=j4HGOpBWvXM     68만회             2년 전
# 17  youtube.com/watch?v=ufupPuN8VVw     56만회           10개월 전
# 18  youtube.com/watch?v=5U6rjsYJ8vU     707회             1일 전
# 19  youtube.com/watch?v=tMIl7fcVXJY    2.8천회             3주 전
# 20  youtube.com/watch?v=ExaatgwYqfU     62만회             3년 전
# 21  youtube.com/watch?v=MZKlECVAgdA    7.3만회             2년 전
# 22  youtube.com/watch?v=q5FqMdeCK74    1.2만회  스트리밍 시간: 19시간 전
# 23  youtube.com/watch?v=RMr30hkzu7w    2.2만회            1개월 전
# 24  youtube.com/watch?v=57jM_sjF838    2.4만회           11개월 전
# 25  youtube.com/watch?v=Ewm26mU7FZY     25만회           10개월 전
# 26  youtube.com/watch?v=KhptxxfMQ_Q     25만회             6년 전

# %%
pd.read_csv("playlist_type_youtube.csv")
# Out:
# Empty DataFrame
# Columns: [ch_name, title, link]
# Index: []
