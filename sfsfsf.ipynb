# %%
x = int(input())
count = 1
total = []
while True:
    if count == 53:
        break
    total.append(x)
    print(x)
    print(count)
    x += 1000
    count += 1

bal = 0
for i in total:
    bal += i
    
print(bal)
# Out:
# 1000
# 1000
# 1
# 2000
# 2
# 3000
# 3
# 4000
# 4
# 5000
# 5
# 6000
# 6
# 7000
# 7
# 8000
# 8
# 9000
# 9
# 10000
# 10
# 11000
# 11
# 12000
# 12
# 13000
# 13
# 14000
# 14
# 15000
# 15
# 16000
# 16
# 17000
# 17
# 18000
# 18
# 19000
# 19
# 20000
# 20
# 21000
# 21
# 22000
# 22
# 23000
# 23
# 24000
# 24
# 25000
# 25
# 26000
# 26
# 27000
# 27
# 28000
# 28
# 29000
# 29
# 30000
# 30
# 31000
# 31
# 32000
# 32
# 33000
# 33
# 34000
# 34
# 35000
# 35
# 36000
# 36
# 37000
# 37
# 38000
# 38
# 39000
# 39
# 40000
# 40
# 41000
# 41
# 42000
# 42
# 43000
# 43
# 44000
# 44
# 45000
# 45
# 46000
# 46
# 47000
# 47
# 48000
# 48
# 49000
# 49
# 50000
# 50
# 51000
# 51
# 52000
# 52
# 1378000

# %%
x = int(input())
count = 1
total = []
while True:
    if count == 53:
        break
    total.append(x)
    print(x)
    print(count)
    x -= 1000
    count += 1

bal = 0
for i in total:
    bal += i
    
print(bal)
# Out:
# 52000
# 52000
# 1
# 51000
# 2
# 50000
# 3
# 49000
# 4
# 48000
# 5
# 47000
# 6
# 46000
# 7
# 45000
# 8
# 44000
# 9
# 43000
# 10
# 42000
# 11
# 41000
# 12
# 40000
# 13
# 39000
# 14
# 38000
# 15
# 37000
# 16
# 36000
# 17
# 35000
# 18
# 34000
# 19
# 33000
# 20
# 32000
# 21
# 31000
# 22
# 30000
# 23
# 29000
# 24
# 28000
# 25
# 27000
# 26
# 26000
# 27
# 25000
# 28
# 24000
# 29
# 23000
# 30
# 22000
# 31
# 21000
# 32
# 20000
# 33
# 19000
# 34
# 18000
# 35
# 17000
# 36
# 16000
# 37
# 15000
# 38
# 14000
# 39
# 13000
# 40
# 12000
# 41
# 11000
# 42
# 10000
# 43
# 9000
# 44
# 8000
# 45
# 7000
# 46
# 6000
# 47
# 5000
# 48
# 4000
# 49
# 3000
# 50
# 2000
# 51
# 1000
# 52
# 1378000
